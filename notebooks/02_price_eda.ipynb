# %% [markdown]
# # Steam Games Pricing EDA
#
# This notebook focuses on whether the Steam games dataset can support a market-aligned price model. The goal is to audit the target variable, understand discount behavior, compare prices across game metadata, and decide which features are safe for pre-release and post-release pricing models.

# %%
import csv
from collections import Counter

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 120)
pd.set_option("display.max_colwidth", 140)
sns.set_theme(style="whitegrid")

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "data" / "games.csv").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"

# %% [markdown]
# ## 0. Load data safely
#
# The raw CSV header merges `Discount` and `DLC count` into one label. The loader repairs that header, converts obvious numeric and boolean columns, and parses release dates for pricing analysis.

# %%
NUMERIC_COLS = [
    "Peak CCU",
    "Required age",
    "Price",
    "Discount",
    "DLC count",
    "Metacritic score",
    "User score",
    "Positive",
    "Negative",
    "Score rank",
    "Achievements",
    "Recommendations",
    "Average playtime forever",
    "Average playtime two weeks",
    "Median playtime forever",
    "Median playtime two weeks",
]

BOOL_COLS = ["Windows", "Mac", "Linux"]


def load_games_csv(path):
    rows = []
    with open(path, newline="", encoding="utf-8") as f:
        reader = csv.reader(f)
        raw_header = next(reader)
        header = raw_header[:7] + ["Discount", "DLC count"] + raw_header[8:]

        for raw_row in reader:
            if len(raw_row) != len(header):
                raise ValueError(f"Unexpected row length {len(raw_row)}")
            rows.append(raw_row)

    df = pd.DataFrame(rows, columns=header)

    df["AppID"] = pd.to_numeric(df["AppID"], errors="coerce").astype("Int64")
    for col in NUMERIC_COLS:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    for col in BOOL_COLS:
        df[col] = df[col].map({"True": True, "False": False})

    df["Release date parsed"] = pd.to_datetime(df["Release date"], format="%b %d, %Y", errors="coerce")
    df["Release year"] = df["Release date parsed"].dt.year
    df["Review count"] = df["Positive"].fillna(0) + df["Negative"].fillna(0)
    df["Positive share"] = np.where(df["Review count"] > 0, df["Positive"] / df["Review count"], np.nan)

    return df


df = load_games_csv(DATA_DIR / "games.csv")
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (122611, 44)
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  Discount  DLC count  \
# 0            0 - 0         0             0   0.00         0          0
# 1        0 - 20000         0             0   5.24        65          0
# 2        0 - 20000         0             0   4.99         0          0
# 3        0 - 20000         1             0   8.99         0          1
# 4        0 - 20000         0             0   4.99         0          0
#
#                                                                                                                                 About the game  \
# 0
# 1  Springtime, April: when the cherry trees come into full bloom. The protagonist Yukinari Sanada has returned to his hometown in Kanagawa ...
# 2  Immerse yourself in the most beloved, mystical and entrancing world of Edgar Allan Poe's ''The Raven!'' This work reflected the image of...
# 3  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' It's been three years since I've repeated such greetings. Hiyoro, who couldn't avoid Hakko...
# 4  Its not just a Maze; its a Quest! Enter the captivating realm of Maze Quest, where each unexpected turn presents fresh challenges, hidde...
#
#                           Supported languages Full audio languages Reviews  \
# 0                                          []                   []
# 1                                 ['English']                   []
# 2  ['English', 'French', 'German', 'Russian']                   []
# 3                                  ['Korean']           ['Korean']
# 4                                 ['English']          ['English']
#
#                                                                                                                                   Header image  \
# 0                                           https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2539430/header.jpg?t=1699268702
# 1                                            https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/496350/header.jpg?t=1725519097
# 2                                           https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1034400/header.jpg?t=1687434115
# 3                                           https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/3292190/header.jpg?t=1742217574
# 4  https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/3631080/2a78ae30e350862e415889f097e422855eca25b9/header.jpg?t=1746637727
#
#                                        Website  \
# 0
# 1               http://mangagamer.org/supipara
# 2        https://www.facebook.com/8FloorGames/
# 3
# 4  https://www.realityexpanded.com/books-games
#
#                             Support url                Support email  Windows  \
# 0                                                                        True
# 1                 http://mangagamer.com       support@mangagamer.com     True
# 2  https://www.facebook.com/8FloorGames           support@8floor.net     True
# 3                                              yujingamesc@gmail.com     True
# 4       https://www.realityexpanded.com  support@realityexpanded.com     True
#
#      Mac  Linux  Metacritic score Metacritic url  User score  Positive  \
# 0  False  False                 0                          0         0
# 1  False  False                 0                          0       252
# 2   True  False                 0                          0        21
# 3  False  False                 0                          0         0
# 4  False  False                 0                          0         0
#
#    Negative  Score rank  Achievements  Recommendations  \
# 0         0         NaN             0                0
# 1         3         NaN             0              231
# 2         3         NaN             0                0
# 3         0         NaN            19                0
# 4         0         NaN             0                0
#
#                                                                                                                                          Notes  \
# 0
# 1
# 2
# 3  The game includes the following elements. 1. General Mature Content : Revealing outfits; sexual stimulation; sexual innuendo; sex-relate...
# 4
#
#    Average playtime forever  Average playtime two weeks  \
# 0                         0                           0
# 1                         8                           0
# 2                         0                           0
# 3                         0                           0
# 4                         0                           0
#
#    Median playtime forever  Median playtime two weeks            Developers  \
# 0                        0                          0
# 1                        8                          0                minori
# 2                        0                          0           Somer Games
# 3                        0                          0                 유진게임즈
# 4                        0                          0  Reality Expanded LLC
#
#              Publishers  \
# 0
# 1            MangaGamer
# 2                8floor
# 3                 유진게임즈
# 4  Reality Expanded LLC
#
#                                                      Categories  \
# 0
# 1  Single-player,Steam Trading Cards,Steam Cloud,Family Sharing
# 2                                  Single-player,Family Sharing
# 3               Single-player,Steam Achievements,Family Sharing
# 4       Single-player,VR Only,Steam Leaderboards,Family Sharing
#
#                     Genres  \
# 0
# 1                Adventure
# 2                   Casual
# 3  Casual,Indie,Simulation
# 4      Action,Early Access
#
#                                                                                                                                           Tags  \
# 0
# 1                                                                                                            Adventure,Visual Novel,Anime,Cute
# 2  Casual,Card Game,Solitaire,Puzzle,Hidden Object,2D,Colorful,Stylized,Logic,Mystery,Atmospheric,Family Friendly,PvE,Tutorial,Singleplayer...
# 3
# 4
#
#                                                                                                                                    Screenshots  \
# 0  https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2539430/ss_7d9504b958d0b143d053d31cb74b375daba338d6.1920x1080.jpg?t=1...
# 1  https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/496350/ss_0a5ff85870a1c2221e495b75a5c7b9e248eb3249.1920x1080.jpg?t=17...
# 2  https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1034400/ss_12d8bb27a16046fe548818dcd0f5d7d0e2038179.1920x1080.jpg?t=1...
# 3  https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/3292190/ss_87f071dbf846e7832ff49d68b0d7a8b6509bcda6.1920x1080.jpg?t=1...
# 4  https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/3631080/3c3874df57f1a1a1f544e81ee21581f8b52140b5/ss_3c3874df57f1a1a1f...
#
#   Movies Release date parsed  Release year  Review count  Positive share
# 0                 2023-08-01          2023             0             NaN
# 1                 2016-07-29          2016           255        0.988235
# 2                 2019-05-06          2019            24        0.875000
# 3                 2024-10-31          2024             0             NaN
# 4                 2025-04-24          2025             0             NaN

# %% [markdown]
# ## 1. Price target audit
#
# Before modeling, check whether `Price` behaves like a usable target. The key questions are how many games are free, how skewed paid prices are, and whether there are strange outliers or placeholder values.

# %%
price_summary = pd.Series({
    "total_games": len(df),
    "missing_price": df["Price"].isna().sum(),
    "free_games": df["Price"].eq(0).sum(),
    "paid_games": df["Price"].gt(0).sum(),
    "negative_prices": df["Price"].lt(0).sum(),
})
price_summary.to_frame("count")
# Out:
#                   count
# total_games      122611
# missing_price         0
# free_games        26206
# paid_games        96405
# negative_prices       0

# %%
paid = df[df["Price"] > 0].copy()

paid["Price"].describe(percentiles=[0.01, 0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).to_frame("price")
# Out:
#               price
# count  96405.000000
# mean       6.060397
# std       13.851424
# min        0.490000
# 1%         0.490000
# 5%         0.590000
# 10%        0.790000
# 25%        1.490000
# 50%        3.490000
# 75%        6.990000
# 90%       11.990000
# 95%       15.990000
# 99%       34.990000
# max      999.980000

# %%
common_prices = (
    paid["Price"]
    .round(2)
    .value_counts()
    .head(25)
    .rename_axis("price")
    .reset_index(name="game_count")
)
common_prices["pct_of_paid"] = (common_prices["game_count"] / len(paid) * 100).round(2)
common_prices
# Out:
#     price  game_count  pct_of_paid
# 0    0.99        8914         9.25
# 1    4.99        8102         8.40
# 2    1.99        6640         6.89
# 3    2.99        6344         6.58
# 4    9.99        4641         4.81
# 5    3.99        4561         4.73
# 6    0.49        3642         3.78
# 7    5.99        3122         3.24
# 8    2.49        2273         2.36
# 9    7.99        2178         2.26
# 10   1.49        2172         2.25
# 11   6.99        2126         2.21
# 12  14.99        2112         2.19
# 13   0.59        1403         1.46
# 14   8.99        1355         1.41
# 15  19.99        1345         1.40
# 16   0.79        1306         1.35
# 17  11.99        1184         1.23
# 18   3.49        1134         1.18
# 19   7.49        1127         1.17
# 20   1.19        1053         1.09
# 21   4.49         929         0.96
# 22   0.55         889         0.92
# 23   0.89         836         0.87
# 24   2.39         830         0.86

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

sns.histplot(paid["Price"], bins=80, ax=axes[0], color="#4C78A8")
axes[0].set_title("Paid game price distribution")
axes[0].set_xlabel("Price")

sns.histplot(np.log1p(paid["Price"]), bins=80, ax=axes[1], color="#F58518")
axes[1].set_title("log1p(price) distribution")
axes[1].set_xlabel("log1p(Price)")

plt.tight_layout()

# %%
paid.sort_values("Price", ascending=False)[
    ["AppID", "Name", "Price", "Discount", "Genres", "Tags", "Release year", "Recommendations", "Review count"]
].head(25)
# Out:
#           AppID                                   Name   Price  Discount  \
# 41088   2504210     The Leverage Game Business Edition  999.98         0
# 68275   2499620                      The Leverage Game  999.98         0
# 34463   1200520      Ascent Free-Roaming VR Experience  999.00         0
# 31935   3013840                              True Love  500.00         0
# 77652   1105450                  Aartform Curvy 3D 4.0  299.99         0
# 85479    253670                  Aartform Curvy 3D 3.0  299.90         0
# 102212   502570                          Houdini Indie  269.99         0
# 63331   2663780             Hidden World 6 Top-Down 3D  199.99         0
# 78623   3471100                How Much Items - Plants  199.99         0
# 92042   4187570                            Nitro Drive  199.99         0
# 34249   2235760                           Tanks Battle  199.99         0
# 116626  1989200                         Space Crafting  199.99         0
# 64112   1912710    Hidden Post-Apocalyptic Top-Down 3D  199.99         0
# 331     2023640          Hidden Industries Top-Down 3D  199.99         0
# 4637    2682800             Hidden World 7 Top-Down 3D  199.99         0
# 99726   3120310             3D PUZZLE - Winter Outpost  199.99         0
# 99099    978610             ★Fallalypse ★ Disconnect ❄  199.99         0
# 89342   2108420               Climb Challenge - Castle  199.99         0
# 121405  1912700                 3D PUZZLE - Wood House  199.99         0
# 81531   2385510                          Infinity Fury  199.99         0
# 26947   3602120  ROOM FOOTBALL - Apocalyptic Wasteland  199.99         0
# 15483   2485560     Wedge Lock Scaffolding VR Training  199.99         0
# 75916   3517290               Archaeology - Grass Farm  199.99         0
# 58863   3384050                           Vampire Hunt  199.99         0
# 117358  2388390              3D PUZZLE - Vintage House  199.99         0
#
#                                                                                           Genres  \
# 41088                                                                           Indie,Simulation
# 68275                                                                           Indie,Simulation
# 34463                                                                                     Action
# 31935                                                              Action,Adventure,Casual,Indie
# 77652                                                 Animation & Modeling,Design & Illustration
# 85479                                                                       Animation & Modeling
# 102212              Animation & Modeling,Design & Illustration,Video Production,Game Development
# 63331                        Action,Adventure,Casual,Indie,Racing,RPG,Simulation,Sports,Strategy
# 78623                        Action,Adventure,Casual,Indie,Racing,RPG,Simulation,Sports,Strategy
# 92042                                                                           Action,Adventure
# 34249                                      Action,Adventure,Casual,Indie,RPG,Simulation,Strategy
# 116626                            Action,Adventure,Casual,Indie,Simulation,Strategy,Early Access
# 64112                                          Action,Adventure,Casual,Indie,Simulation,Strategy
# 331                              Action,Adventure,Casual,Indie,Racing,Simulation,Sports,Strategy
# 4637                         Action,Adventure,Casual,Indie,Racing,RPG,Simulation,Sports,Strategy
# 99726                               Action,Adventure,Casual,Indie,RPG,Simulation,Sports,Strategy
# 99099   Action,Adventure,Casual,Indie,Massively Multiplayer,RPG,Simulation,Strategy,Early Access
# 89342                                            Action,Adventure,Casual,Indie,Simulation,Sports
# 121405                                                  Action,Adventure,Casual,Indie,Simulation
# 81531                                                   Action,Adventure,Casual,Indie,Simulation
# 26947                                                       Action,Adventure,Casual,Indie,Sports
# 15483                                                                                 Simulation
# 75916                        Action,Adventure,Casual,Indie,Racing,RPG,Simulation,Sports,Strategy
# 58863                                                                           Action,Adventure
# 117358        Action,Adventure,Casual,Indie,Massively Multiplayer,RPG,Simulation,Sports,Strategy
#
#                                                                                                                                                Tags  \
# 41088
# 68275                   Board Game,Turn-Based Tactics,Simulation,Education,Economy,PvP,Tabletop,2D,Cute,Indie,Logic,Singleplayer,Multiplayer,Hentai
# 34463   Action,Hentai,Nudity,Sexual Content,LGBTQ+,VR,NSFW,Free to Play,Dating Sim,Anime,Horror,Psychological Horror,Multiplayer,Cute,Arena Shoo...
# 31935   Casual,Action-Adventure,Visual Novel,Dating Sim,Walking Simulator,Exploration,Hidden Object,3D,First-Person,Realistic,Cute,Third Person,...
# 77652                                                                                                 Design & Illustration,Animation & Modeling,3D
# 85479                                                                                                                          Animation & Modeling
# 102212             Animation & Modeling,Game Development,3D,Design & Illustration,Indie,Video Production,Procedural Generation,Psychological Horror
# 63331
# 78623
# 92042
# 34249
# 116626  Early Access,Action,Adventure,Casual,Simulation,Strategy,Action RPG,Auto Battler,Board Game,Life Sim,3D Platformer,MOBA,Choose Your Own ...
# 64112   Exploration,Tactical RPG,Hidden Object,3D Platformer,FPS,Puzzle-Platformer,Puzzle,Point & Click,Strategy,Platformer,3D,Walking Simulator...
# 331     Card Battler,Choose Your Own Adventure,Exploration,Racing,CRPG,Outbreak Sim,Sports,Precision Platformer,2D Platformer,Hidden Object,Hack...
# 4637
# 99726
# 99099   Action,Early Access,RPG,Strategy,Indie,Simulation,Adventure,Post-apocalyptic,Zombies,Sci-fi,Exploration,Open World,Casual,Experimental,H...
# 89342   Action,Adventure,Casual,Simulation,RPG,3D Fighter,Action RPG,City Builder,Puzzle,Farming Sim,3D Platformer,Choose Your Own Adventure,Dun...
# 121405  Action,Adventure,Casual,Simulation,Action RPG,Action-Adventure,City Builder,Puzzle,God Game,3D Platformer,Exploration,FPS,Hidden Object,...
# 81531
# 26947
# 15483
# 75916   Action,Adventure,Casual,Racing,RPG,Simulation,Sports,Strategy,3D Fighter,Action Roguelike,Battle Royale,Colony Sim,Point & Click,Rhythm,...
# 58863                                                                   Action,Adventure,Action-Adventure,2D Platformer,2D,Atmospheric,Singleplayer
# 117358
#
#         Release year  Recommendations  Review count
# 41088           2023                0             0
# 68275           2023                0             1
# 34463           2019                0             7
# 31935           2024                0             4
# 77652           2020                0            12
# 85479           2013                0            45
# 102212          2018              235           251
# 63331           2023                0             0
# 78623           2025                0             0
# 92042           2025                0             0
# 34249           2022                0             0
# 116626          2022                0            38
# 64112           2022                0            23
# 331             2022                0            12
# 4637            2023                0             0
# 99726           2024                0             0
# 99099           2019                0            22
# 89342           2022                0            11
# 121405          2022                0            34
# 81531           2025                0             0
# 26947           2025                0             0
# 15483           2024                0             0
# 75916           2025                0            11
# 58863           2025                0             1
# 117358          2023                0             0

# %% [markdown]
# ## 2. Discount handling
#
# The model should learn market-aligned list price, not temporary sale price. This section checks whether discounted rows should be filtered from the first training set.

# %%
discount_summary = pd.Series({
    "missing_discount": df["Discount"].isna().sum(),
    "discount_zero": df["Discount"].eq(0).sum(),
    "discount_positive": df["Discount"].gt(0).sum(),
    "discount_negative": df["Discount"].lt(0).sum(),
})
discount_summary.to_frame("count")
# Out:
#                    count
# missing_discount       0
# discount_zero      81930
# discount_positive  40681
# discount_negative      0

# %%
discounted = paid[paid["Discount"] > 0].copy()

print(f"Discounted paid games: {len(discounted):,} / {len(paid):,} ({len(discounted) / len(paid) * 100:.2f}%)")
display(discounted["Discount"].describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).to_frame("discount"))

discounted.sort_values(["Discount", "Price"], ascending=False)[
    ["AppID", "Name", "Price", "Discount", "Genres", "Release year"]
].head(25)
# Out:
# Discounted paid games: 40,642 / 96,405 (42.16%)
#            discount
# count  40642.000000
# mean      55.312583
# std       21.571579
# min       10.000000
# 25%       40.000000
# 50%       51.000000
# 75%       75.000000
# 90%       84.000000
# 95%       90.000000
# 99%       91.000000
# max      100.000000
#           AppID                           Name   Price  Discount  \
# 29407   1200580                    One Gun Guy    0.69       100
# 117893   460960              The Deed: Dynasty    0.59       100
# 69662   3230900  Hidden Storehouse Top-Down 3D  199.99        95
# 97762   3822960                      Zekertune   30.76        95
# 75989   1368670   Beach Volleyball Competition   14.50        95
# 11201   2085510                Fly Fly Tuk Tuk    9.99        95
# 15383   2363810           Long Truck Simulator    9.99        95
# 25406   2247790                    Snake Robot    9.99        95
# 35135   2471600              Impossible Stunts    9.99        95
# 41123   2203480                Reach the Moon!    9.99        95
# 54275   1927710        Supreme Race on Highway    9.99        95
# 72939   1977280    School Bus Driver Simulator    9.99        95
# 83966   2124660                 Fix My Cat Doc    9.99        95
# 94502   2387830           People Jumping Tower    9.99        95
# 3373    1917740              The Ultimate Shot    4.99        95
# 3561    2018850           Fire Truck Simulator    4.99        95
# 56935   2394600            Last Day of Zombies    4.99        95
# 57595   2374570                    Car Parkour    4.99        95
# 87054   2017020                    Cowboy Girl    4.99        95
# 88918   1927540               The Hidden Ghost    4.99        95
# 95541   2400760         Bike Offroad Simulator    4.99        95
# 97929   1935410      The Smash Cars Tournament    4.99        95
# 9530    1222680           Need for Speed™ Heat    3.49        95
# 10254    644130                          Foxus    2.99        95
# 39152   2996430                          Urban    2.99        95
#
#                                                    Genres  Release year
# 29407                                        Action,Indie          2022
# 117893                                Adventure,Indie,RPG          2016
# 69662              Action,Adventure,Casual,Indie,Strategy          2024
# 97762                                              Casual          2025
# 75989                            Action,Simulation,Sports          2020
# 11201               Action,Indie,Racing,Simulation,Sports          2022
# 15383            Adventure,Indie,Racing,Simulation,Sports          2023
# 25406            Adventure,Casual,Indie,Simulation,Sports          2023
# 35135     Action,Adventure,Casual,Indie,Racing,Simulation          2023
# 41123          Adventure,Casual,Indie,Simulation,Strategy          2023
# 54275               Casual,Indie,Racing,Simulation,Sports          2022
# 72939                      Casual,Indie,Racing,Simulation          2022
# 83966            Adventure,Casual,Indie,Simulation,Sports          2022
# 94502                    Casual,Indie,Simulation,Strategy          2023
# 3373               Action,Adventure,Casual,Indie,Strategy          2022
# 3561              Indie,Racing,Simulation,Sports,Strategy          2022
# 56935                      Action,Casual,Indie,Simulation          2023
# 57595               Casual,Indie,Racing,Simulation,Sports          2023
# 87054   Action,Adventure,Casual,Indie,Simulation,Strategy          2022
# 88918                   Adventure,Casual,Indie,Simulation          2022
# 95541                             Indie,Racing,Simulation          2023
# 97929               Casual,Indie,Racing,Simulation,Sports          2022
# 9530                       Action,Adventure,Racing,Sports          2020
# 10254                                    Action,Adventure          2018
# 39152                                Action,Adventure,RPG          2024

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=paid.assign(has_discount=paid["Discount"].gt(0)), x="has_discount", y="Price", showfliers=False)
plt.title("Paid game price by discount status")
plt.xlabel("Has active discount")
plt.ylabel("Price")
plt.tight_layout()

# %% [markdown]
# ## 3. Feature-price relationships
#
# These checks show which pre-release metadata fields plausibly explain price differences.

# %%
analysis_df = paid[paid["Discount"].fillna(0).eq(0)].copy()
print(f"Paid, non-discounted analysis rows: {len(analysis_df):,}")
analysis_df[["Price", "Required age", "DLC count", "Achievements", "Release year"]].describe().T
# Out:
# Paid, non-discounted analysis rows: 55,763
#                 count         mean         std      min      25%      50%  \
# Price         55763.0     7.140587   17.398376     0.49     1.99     3.99
# Required age  55763.0     0.111974    1.343079     0.00     0.00     0.00
# DLC count     55763.0     0.279182    7.100153     0.00     0.00     0.00
# Achievements  55763.0    15.887381  121.456811     0.00     0.00     1.00
# Release year  55763.0  2021.427398    3.176048  2000.00  2019.00  2022.00
#
#                   75%      max
# Price            7.99   999.98
# Required age     0.00    21.00
# DLC count        0.00   967.00
# Achievements    17.00  5394.00
# Release year  2024.00  2026.00

# %%
def split_items(series):
    return (
        series.dropna()
        .astype(str)
        .str.split(",")
        .explode()
        .str.strip()
        .loc[lambda s: s.ne("")]
    )


def price_by_multilabel(df, column, min_count=200, top_n=25):
    exploded = (
        df[["Price", column]]
        .dropna(subset=[column])
        .assign(item=lambda x: x[column].astype(str).str.split(","))
        .explode("item")
    )
    exploded["item"] = exploded["item"].str.strip()
    exploded = exploded[exploded["item"].ne("")]

    summary = (
        exploded.groupby("item")["Price"]
        .agg(game_count="size", median_price="median", mean_price="mean")
        .query("game_count >= @min_count")
        .sort_values("median_price", ascending=False)
        .head(top_n)
    )
    return summary

# %%
genre_price = price_by_multilabel(analysis_df, "Genres", min_count=200, top_n=25)
genre_price
# Out:
#                        game_count  median_price  mean_price
# item
# Animation & Modeling          202          9.49   23.685495
# Design & Illustration         279          8.99   18.196416
# Early Access                 6809          6.39    8.723958
# Massively Multiplayer         699          4.99   10.777024
# RPG                          9603          4.99   10.020863
# Simulation                  11584          4.99   10.448783
# Sports                       2579          4.99   17.452369
# Strategy                    11091          4.99    9.451236
# Utilities                     528          4.99   11.138277
# Violent                       300          4.99    6.136600
# Adventure                   21454          4.79    7.973652
# Racing                       2106          4.79   16.656059
# Action                      23036          4.32    7.986267
# Indie                       40854          3.99    6.577618
# Casual                      25433          2.99    6.598489

# %%
tag_price = price_by_multilabel(analysis_df, "Tags", min_count=300, top_n=30)
tag_price
# Out:
#                        game_count  median_price  mean_price
# item
# Colony Sim                    303          7.99   15.657987
# Moddable                      333          7.39   10.318649
# 6DOF                          357          6.99    9.446555
# VR                           3260          6.99    9.552420
# Early Access                 6096          6.39    9.007070
# Grand Strategy                365          6.24   13.225123
# Crafting                     1438          5.99    9.990438
# Building                     1765          5.99   10.074782
# Turn-Based                    776          5.99    8.536959
# Party-Based RPG               567          5.99    9.920335
# Sandbox                      1969          5.99    9.651173
# Tactical RPG                  672          5.99    9.106473
# Economy                       757          5.99    9.818362
# Base-Building                1070          5.99    9.078262
# City Builder                  670          5.99   14.642090
# Software                      328          5.29   11.865274
# Management                   1749          5.24    8.524059
# JRPG                         1033          5.19    8.641394
# Online Co-Op                 1152          5.09    8.401944
# Open World                   2471          5.00    9.547357
# Team-Based                    505          5.00    8.244436
# Historical                    986          5.00    8.924767
# Military                      857          4.99    9.058215
# Modern                        657          4.99    6.839604
# Metroidvania                  583          4.99    9.897890
# Medieval                     1761          4.99    7.132232
# Multiplayer                  3714          4.99    8.868064
# Multiple Endings             2394          4.99    6.312615
# Massively Multiplayer         498          4.99    8.702651
# Mythology                     496          4.99    6.968649

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 10))

sns.barplot(data=genre_price.reset_index(), x="median_price", y="item", ax=axes[0], color="#54A24B")
axes[0].set_title("Highest median price genres")
axes[0].set_xlabel("Median price")
axes[0].set_ylabel("")

sns.barplot(data=tag_price.head(20).reset_index(), x="median_price", y="item", ax=axes[1], color="#E45756")
axes[1].set_title("Highest median price tags")
axes[1].set_xlabel("Median price")
axes[1].set_ylabel("")

plt.tight_layout()

# %%
platform_summary = []
for col in ["Windows", "Mac", "Linux"]:
    subset = analysis_df[analysis_df[col].eq(True)]
    platform_summary.append({
        "platform": col,
        "game_count": len(subset),
        "median_price": subset["Price"].median(),
        "mean_price": subset["Price"].mean(),
    })

pd.DataFrame(platform_summary).sort_values("median_price", ascending=False)
# Out:
#   platform  game_count  median_price  mean_price
# 1      Mac        9472          4.99   10.280668
# 2    Linux        7031          4.79   11.169617
# 0  Windows       55736          3.99    7.138166

# %%
year_price = (
    analysis_df.dropna(subset=["Release year"])
    .assign(Release_year=lambda x: x["Release year"].astype(int))
    .groupby("Release_year")["Price"]
    .agg(game_count="size", median_price="median", mean_price="mean")
    .query("game_count >= 50")
)

plt.figure(figsize=(12, 5))
sns.lineplot(data=year_price.reset_index(), x="Release_year", y="median_price", marker="o")
plt.title("Median paid non-discounted price by release year")
plt.xlabel("Release year")
plt.ylabel("Median price")
plt.tight_layout()

year_price.tail(15)
# Out:
#               game_count  median_price  mean_price
# Release_year
# 2012                  89         4.990    7.579888
# 2013                 143         4.990    8.739021
# 2014                 588         4.990    6.584966
# 2015                1117         4.990    6.521415
# 2016                1916         4.990    6.501968
# 2017                3059         3.990    6.365505
# 2018                3984         2.995    6.206609
# 2019                3906         3.990    6.369508
# 2020                4498         3.990    6.543864
# 2021                5382         3.990    6.963831
# 2022                5418         3.990    7.475862
# 2023                6072         3.990    7.977851
# 2024                7667         3.990    8.354552
# 2025               11493         4.490    7.039917
# 2026                  71         4.190    5.931268

# %%
binned = analysis_df.copy()
binned["DLC count bin"] = pd.cut(binned["DLC count"].fillna(0), bins=[-1, 0, 1, 5, 20, np.inf], labels=["0", "1", "2-5", "6-20", "21+"])
binned["Achievements bin"] = pd.cut(binned["Achievements"].fillna(0), bins=[-1, 0, 10, 50, 100, np.inf], labels=["0", "1-10", "11-50", "51-100", "101+"])

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
sns.boxplot(data=binned, x="DLC count bin", y="Price", showfliers=False, ax=axes[0])
axes[0].set_title("Price by DLC count bin")
axes[0].set_xlabel("DLC count")

sns.boxplot(data=binned, x="Achievements bin", y="Price", showfliers=False, ax=axes[1])
axes[1].set_title("Price by achievements bin")
axes[1].set_xlabel("Achievements")

plt.tight_layout()

# %% [markdown]
# ## 4. Outcome variables and leakage risk
#
# Outcome variables are useful for gamer-facing value assessment, but they are not available to developers before launch. This section quantifies how strongly they relate to price so we can keep pre-release and post-release models separate.

# %%
outcome_cols = [
    "Peak CCU",
    "Positive",
    "Negative",
    "Review count",
    "Positive share",
    "Recommendations",
    "Average playtime forever",
    "Median playtime forever",
    "Metacritic score",
]

corr_df = analysis_df[["Price"] + outcome_cols].copy()
for col in ["Price", "Peak CCU", "Positive", "Negative", "Review count", "Recommendations", "Average playtime forever", "Median playtime forever"]:
    corr_df[f"log1p_{col}"] = np.log1p(corr_df[col].fillna(0))

corr = corr_df.corr(numeric_only=True)[["Price", "log1p_Price"]].sort_values("log1p_Price", ascending=False)
corr
# Out:
#                                    Price  log1p_Price
# log1p_Price                     0.614117     1.000000
# Price                           1.000000     0.614117
# log1p_Peak CCU                  0.068454     0.157347
# log1p_Recommendations           0.043611     0.132626
# log1p_Average playtime forever  0.035284     0.126943
# log1p_Median playtime forever   0.034475     0.126121
# log1p_Negative                  0.043351     0.104886
# log1p_Review count              0.015251     0.085017
# log1p_Positive                  0.008113     0.082401
# Metacritic score                0.019317     0.070611
# Negative                        0.039591     0.054275
# Recommendations                 0.034631     0.049821
# Review count                    0.029919     0.043512
# Peak CCU                        0.033460     0.042734
# Median playtime forever         0.018201     0.041818
# Average playtime forever        0.018181     0.040571
# Positive                        0.026550     0.039078
# Positive share                 -0.066221    -0.038498

# %%
sample = analysis_df.sample(min(10000, len(analysis_df)), random_state=42)

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
sns.scatterplot(data=sample, x=np.log1p(sample["Review count"].fillna(0)), y=np.log1p(sample["Price"]), alpha=0.25, ax=axes[0])
axes[0].set_title("Price vs review count")
axes[0].set_xlabel("log1p(review count)")
axes[0].set_ylabel("log1p(price)")

sns.scatterplot(data=sample, x=np.log1p(sample["Recommendations"].fillna(0)), y=np.log1p(sample["Price"]), alpha=0.25, ax=axes[1])
axes[1].set_title("Price vs recommendations")
axes[1].set_xlabel("log1p(recommendations)")
axes[1].set_ylabel("log1p(price)")

plt.tight_layout()

# %% [markdown]
# ## 5. Comparable-game sanity checks
#
# Before building KNN comparables, inspect whether the metadata fields contain enough signal to group similar games in a useful way.

# %%
def search_games(query, limit=20):
    mask = df["Name"].fillna("").str.contains(query, case=False, regex=False)
    cols = ["AppID", "Name", "Price", "Discount", "Genres", "Categories", "Tags", "Release year", "Recommendations"]
    return df.loc[mask, cols].sort_values(["Recommendations", "Price"], ascending=False).head(limit)


search_games("hades")
# Out:
#           AppID                                                   Name  Price  \
# 70333   1145360                                                  Hades   7.49
# 20861   1145350                                               Hades II  22.49
# 49280   1022310             Warhammer Underworlds - Shadespire Edition   2.99
# 46742   1399930                                    Furry Shades of Gay   2.09
# 70146   1724050                   Furry Shades of Gay 2: A Shade Gayer   2.99
# 98474   1678140                                       Shades of Sakura   0.77
# 115462  1953540                     Furry Shades of Gay 3: Still Gayer   2.99
# 42785   1932190                             Outbreak: Shades of Horror  20.99
# 109425   653020                                      Lumins and Shades  14.99
# 46179   1532750                       Jigsaw Pieces 2 - Shades of Mood   9.99
# 106924  3101140    Grim Tales: All Shades of Black Collector's Edition   6.99
# 52040   3107090             Outbreak: Shades of Horror Chromatic Split   6.24
# 2807    1240680                           Hades Ultimate Fighting Ball   5.99
# 21416   2540540                                Escape Hades's jails VR   5.99
# 118915  4184680                                          Shades Of War   5.99
# 12997    466020  Off the Record: The Linden Shades Collector's Edition   4.99
# 93386    696010         Otherworld: Shades of Fall Collector's Edition   4.99
# 97792   2447330                            Hades Nebula (C64/Spectrum)   3.99
# 60633   1496530                                       Cinders Of Hades   2.99
# 9448    1194940                                        Tower of Shades   1.99
#
#         Discount                             Genres  \
# 70333         70                   Action,Indie,RPG
# 20861         25                   Action,Indie,RPG
# 49280         90                    Casual,Strategy
# 46742         70              Casual,Indie,Strategy
# 70146         70              Casual,Indie,Strategy
# 98474         61         Adventure,Casual,Indie,RPG
# 115462        70                       Casual,Indie
# 42785         30  Action,Adventure,RPG,Early Access
# 109425         0              Casual,Indie,Strategy
# 46179          0             Adventure,Casual,Indie
# 106924        50                   Adventure,Casual
# 52040         75         Action,Adventure,Indie,RPG
# 2807           0   Action,Indie,Sports,Early Access
# 21416          0       Adventure,Indie,Early Access
# 118915         0                    Action,Strategy
# 12997          0                   Adventure,Casual
# 93386         50                   Adventure,Casual
# 97792          0                             Action
# 60633          0                      Action,Casual
# 9448           0                          Indie,RPG
#
#                                                                                                                                          Categories  \
# 70333   Single-player,Steam Achievements,Full controller support,Steam Trading Cards,Captions available,Steam Cloud,Remote Play on Phone,Remote ...
# 20861                    Single-player,Steam Achievements,Full controller support,Steam Trading Cards,Captions available,Steam Cloud,Family Sharing
# 49280                                                                                                    Multi-player,PvP,Online PvP,Family Sharing
# 46742                                                               Single-player,Steam Achievements,Steam Trading Cards,Steam Cloud,Family Sharing
# 70146                                                               Single-player,Steam Achievements,Steam Trading Cards,Steam Cloud,Family Sharing
# 98474                                                                           Single-player,Steam Achievements,Steam Trading Cards,Family Sharing
# 115462                                                              Single-player,Steam Achievements,Steam Trading Cards,Steam Cloud,Family Sharing
# 42785                                                          Single-player,Multi-player,Co-op,Online Co-op,Full controller support,Family Sharing
# 109425                                                                      Single-player,Steam Achievements,Full controller support,Family Sharing
# 46179                                                                                         Single-player,Captions available,Stats,Family Sharing
# 106924                                                                                                                 Single-player,Family Sharing
# 52040                                                              Single-player,Steam Achievements,Partial Controller Support,Stats,Family Sharing
# 2807                                                                                  Multi-player,PvP,Online PvP,Co-op,Online Co-op,Family Sharing
# 21416                                                       Single-player,Multi-player,Co-op,Online Co-op,Steam Achievements,VR Only,Family Sharing
# 118915  Single-player,Multi-player,PvP,Online PvP,Shared/Split Screen PvP,Shared/Split Screen,Steam Achievements,Full controller support,Custom ...
# 12997                                                                                                                  Single-player,Family Sharing
# 93386                                                                                                                  Single-player,Family Sharing
# 97792                                                                           Single-player,Partial Controller Support,Steam Cloud,Family Sharing
# 60633                                    Single-player,Steam Achievements,Tracked Controller Support,VR Supported,Steam Leaderboards,Family Sharing
# 9448                                                                                                                   Single-player,Family Sharing
#
#                                                                                                                                                Tags  \
# 70333   Action Roguelike,Rogue-lite,Hack and Slash,Indie,Mythology,Action,Rogue-like,Singleplayer,Great Soundtrack,Story Rich,RPG,Dungeon Crawle...
# 20861   Action,Rogue-like,Rogue-lite,Hack and Slash,RPG,Action Roguelike,Mythology,Dungeon Crawler,Action RPG,Isometric,Hand-drawn,Female Protag...
# 49280   Turn-Based Tactics,Card Battler,Casual,Grand Strategy,Tactical RPG,Wargame,PvP,Competitive,Turn-Based,Board Game,Card Game,Tabletop,Turn...
# 46742
# 70146
# 98474   Hentai,Dating Sim,Mature,Puzzle,Visual Novel,NSFW,Casual,Anime,Indie,Adventure,Singleplayer,Sexual Content,Story Rich,RPG,Female Protago...
# 115462
# 42785
# 109425  Puzzle,Logic,Nonlinear,Exploration,Cute,Casual,Family Friendly,Pixel Graphics,2D,Strategy,Top-Down,Grid-Based Movement,Singleplayer,Atmo...
# 46179   Puzzle,Tabletop,2D,Cute,Adventure,Top-Down,Relaxing,Colorful,Realistic,Family Friendly,Logic,Nature,Old School,Singleplayer,Arcade,Puzzl...
# 106924                                                      Adventure,Casual,Hidden Object,Point & Click,Puzzle,Fantasy,Atmospheric,Singleplayer,2D
# 52040   Exploration,Third-Person Shooter,FPS,PvE,Shooter,RPG,Action RPG,Arcade,Action-Adventure,Female Protagonist,3D,Third Person,First-Person,...
# 2807                                                Action,Sports,Indie,Early Access,Gore,Violent,Sexual Content,Nudity,Multiplayer,Mature,Fighting
# 21416
# 118915
# 12997                                                                                                                Adventure,Casual,Hidden Object
# 93386                                                                                                                Adventure,Casual,Hidden Object
# 97792
# 60633   Bullet Hell,Shoot 'Em Up,Casual,Shooter,Arcade,3D,First-Person,VR,Dragons,Relaxing,Action,Demons,Fantasy,Magic,Physics,Destruction,Singl...
# 9448    RPG,Indie,Turn-Based Combat,Singleplayer,Action,Fantasy,2D,Pixel Graphics,Short,Female Protagonist,Turn-Based,Great Soundtrack,Difficult...
#
#         Release year  Recommendations
# 70333           2020           271975
# 20861           2025            99709
# 49280           2020             1048
# 46742           2020              791
# 70146           2021              723
# 98474           2021              527
# 115462          2023              370
# 42785           2025                0
# 109425          2023                0
# 46179           2021                0
# 106924          2024                0
# 52040           2024                0
# 2807            2020                0
# 21416           2024                0
# 118915          2025                0
# 12997           2016                0
# 93386           2017                0
# 97792           2023                0
# 60633           2021                0
# 9448            2020                0

# %%
def item_set(row, columns=("Genres", "Categories", "Tags")):
    items = set()
    for col in columns:
        value = row.get(col)
        if pd.isna(value):
            continue
        items.update(part.strip() for part in str(value).split(",") if part.strip())
    return items


def rough_metadata_matches(app_id, limit=15):
    game = df.loc[df["AppID"].eq(app_id)].iloc[0]
    target_items = item_set(game)

    candidates = analysis_df[analysis_df["AppID"].ne(app_id)].copy()
    candidates["metadata_overlap"] = candidates.apply(lambda row: len(target_items & item_set(row)), axis=1)
    candidates["price_difference"] = candidates["Price"] - game["Price"]

    cols = ["AppID", "Name", "Price", "price_difference", "metadata_overlap", "Genres", "Tags", "Recommendations"]
    return candidates.sort_values(["metadata_overlap", "Recommendations"], ascending=False)[cols].head(limit)


# Replace this AppID after using search_games() above.
rough_metadata_matches(1145360)
# Out:
#           AppID                                  Name  Price  \
# 53498   2126370                          Wraithbinder  14.99
# 64691    247080              Crypt of the NecroDancer   2.99
# 34750   1601740                         Corpse Keeper   6.99
# 86309   1144910                      Space Gladiators  14.99
# 10234   1646790                    Striving for Light  13.49
# 12993    266510                          Hand of Fate  19.99
# 100895   456670                        Hand of Fate 2  29.99
# 4691     535480           Sundered®: Eldritch Edition   2.99
# 34330   1048350                           Nigate Tale   4.99
# 48489   2549380                        Cryptical Path  14.99
# 5535    1963670                               Cardbob   9.99
# 57884   1582380                             Midautumn  24.99
# 111007   374320                       DARK SOULS™ III  59.99
# 24922   1369630  ENDER LILIES: Quietus of the Knights   9.99
# 26346    257850                   Hyper Light Drifter  19.99
#
#         price_difference  metadata_overlap  \
# 53498                7.5                24
# 64691               -4.5                19
# 34750               -0.5                19
# 86309                7.5                19
# 10234                6.0                19
# 12993               12.5                18
# 100895              22.5                18
# 4691                -4.5                18
# 34330               -2.5                18
# 48489                7.5                18
# 5535                 2.5                18
# 57884               17.5                18
# 111007              52.5                17
# 24922                2.5                17
# 26346               12.5                17
#
#                                      Genres  \
# 53498         Action,Indie,RPG,Early Access
# 64691                      Action,Indie,RPG
# 34750   Action,Adventure,Indie,RPG,Strategy
# 86309                          Action,Indie
# 10234     Action,Adventure,Casual,Indie,RPG
# 12993                      Action,Indie,RPG
# 100895                     Action,Indie,RPG
# 4691                 Action,Adventure,Indie
# 34330            Action,Adventure,Indie,RPG
# 48489                      Action,Indie,RPG
# 5535             Action,Adventure,Indie,RPG
# 57884         Action,Indie,RPG,Early Access
# 111007                               Action
# 24922                      Action,Indie,RPG
# 26346            Action,Adventure,Indie,RPG
#
#                                                                                                                                                Tags  \
# 53498   Action Roguelike,Rogue-lite,Hack and Slash,Indie,Action,Rogue-like,Singleplayer,RPG,Story Rich,Dungeon Crawler,Replay Value,Isometric,Di...
# 64691   Rhythm,Female Protagonist,Difficult,Rogue-like,Great Soundtrack,Pixel Graphics,Dungeon Crawler,Indie,Music,Local Co-Op,RPG,2D,Action,Rog...
# 34750   Action RPG,Dark,Fantasy,Singleplayer,3D,Hack and Slash,Dungeon Crawler,Replay Value,Difficult,Strategy,Souls-like,Action Roguelike,Rogue...
# 86309   Action,Indie,Rogue-lite,2D,2D Platformer,Hand-drawn,Action Roguelike,Difficult,Singleplayer,Perma Death,Side Scroller,Replay Value,Dunge...
# 10234   Early Access,Action RPG,Hack and Slash,Action Roguelike,Rogue-lite,RPG,Dungeon Crawler,Perma Death,Rogue-like,Action-Adventure,Procedura...
# 12993   Roguelike Deckbuilder,Rogue-like,Deckbuilding,Card Game,Action Roguelike,RPG,Singleplayer,Action,Fantasy,Indie,Choose Your Own Adventure...
# 100895  RPG,Roguelike Deckbuilder,Card Game,Action,Deckbuilding,Rogue-lite,Indie,Action Roguelike,Singleplayer,Board Game,Fantasy,Rogue-like,Dun...
# 4691    Roguevania,Metroidvania,Lovecraftian,Action Roguelike,Indie,Platformer,Hand-drawn,2D,Female Protagonist,Action,Difficult,Adventure,Side ...
# 34330   Action Roguelike,Magic,Indie,Hack and Slash,Action,Rogue-like,Singleplayer,Rogue-lite,Action RPG,Cute,Story Rich,Anime,Dungeon Crawler,D...
# 48489   Action Roguelike,Hack and Slash,Rogue-like,Combat,Story Rich,Procedural Generation,Action,Difficult,Dark Humor,2D Platformer,3D,Rogue-li...
# 5535    Action Roguelike,Hack and Slash,Rogue-lite,Replay Value,Rogue-like,Combat,Action RPG,Action,3D,Dungeon Crawler,Sci-fi,Difficult,Top-Down...
# 57884   Early Access,Indie,Action,Action Roguelike,Rogue-lite,Hack and Slash,Rogue-like,Dungeon Crawler,RPG,Supernatural,Mythology,Singleplayer,...
# 111007  Souls-like,Dark Fantasy,Difficult,RPG,Atmospheric,Lore-Rich,Third Person,Exploration,Story Rich,Action RPG,Co-op,Great Soundtrack,Advent...
# 24922   Metroidvania,Female Protagonist,Souls-like,Dark Fantasy,Singleplayer,Great Soundtrack,Atmospheric,2D,Difficult,Indie,Multiple Endings,Da...
# 26346   Pixel Graphics,Great Soundtrack,Atmospheric,Adventure,Indie,Difficult,Action,Hack and Slash,Singleplayer,Exploration,RPG,2D,Colorful,Top...
#
#         Recommendations
# 53498                 0
# 64691             23196
# 34750              1106
# 86309               412
# 10234               156
# 12993              7958
# 100895             5207
# 4691               4005
# 34330               660
# 48489               130
# 5535                  0
# 57884                 0
# 111007           269868
# 24922             40043
# 26346             14738

# %% [markdown]
# ## 6. Modeling decisions to carry forward
#
# Fill this in after running the notebook:
#
# - Training scope: likely paid games only; decide whether to exclude discounted rows.
# - Target: likely `log1p(Price)`.
# - Pre-release features: `Genres`, `Tags`, `Categories`, platform booleans, `Required age`, `DLC count`, `Achievements`, `Release year`.
# - Post-release features: add review, recommendation, playtime, CCU, and Metacritic fields only for gamer-facing valuation.
# - Comparable-game layer: use metadata vectors to retrieve similar games, then compare actual price, predicted price, and neighbor median price.
# - First modeling notebook: compare median baseline, Ridge, KNN median-price baseline, and sklearn gradient boosting.
